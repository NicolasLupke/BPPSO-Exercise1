# %%
import pm4py

# %%
log = pm4py.read_xes("Dataset\BPI Challenge 2017.xes")
inductive_miner = pm4py.discover_process_tree_inductive(log)
heuristics_miner = pm4py.discover_heuristics_net(log)
dfg_miner, start_activities, end_activities = pm4py.discover_dfg(log)
performance_dfg_miner = pm4py.discover_performance_dfg(log)

# %%
bpmn_inductive = pm4py.convert_to_bpmn(inductive_miner)
bpmn_heuristics = pm4py.convert_to_bpmn(heuristics_miner)

# %%
pm4py.view_dfg(dfg_miner, start_activities, end_activities, format="png")
